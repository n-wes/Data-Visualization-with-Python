# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('top50.csv', encoding = 'cp1252')

# %%
# Our Dataset
data.head(50)
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
# Show top artists
data['Artist.Name'].value_counts().plot(kind = 'bar', figsize = (10,10))
plt.show()
# Change to horizontal bar chart
