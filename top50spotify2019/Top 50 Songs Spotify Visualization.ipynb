# %%
import pandas as pd
import matplotlib.pyplot as plt
import squarify as sq
import seaborn as sns

data = pd.read_csv('top50.csv', encoding = 'cp1252')
data = data.rename(columns={'Unnamed: 0':'Rank'})

def htmap_trunc_fix():
    ### Fix heatmap truncation problem
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    ###

# %%
# Our Dataset
data.head(50)
# Out:
#     Rank                                         Track.Name       Artist.Name  \
# 0      1                                           Señorita      Shawn Mendes
# 1      2                                              China          Anuel AA
# 2      3                      boyfriend (with Social House)     Ariana Grande
# 3      4                    Beautiful People (feat. Khalid)        Ed Sheeran
# 4      5                        Goodbyes (Feat. Young Thug)       Post Malone
# 5      6                  I Don't Care (with Justin Bieber)        Ed Sheeran
# 6      7                                             Ransom         Lil Tecca
# 7      8                                  How Do You Sleep?         Sam Smith
# 8      9                              Old Town Road - Remix         Lil Nas X
# 9     10                                            bad guy     Billie Eilish
# 10    11                                           Callaita         Bad Bunny
# ...

# %%
data.describe()
# Out:
#            Rank  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count  50.00000         50.000000  50.000000      50.00000       50.000000
# mean   25.50000        120.060000  64.060000      71.38000       -5.660000
# std    14.57738         30.898392  14.231913      11.92988        2.056448
# min     1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%    13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%    25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%    37.75000        137.500000  74.750000      79.75000       -4.000000
# max    50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# std    11.118306  22.336024   39.143879       18.995553     11.161596
# ...

# %%
# Show top artists
artist_frequency = data['Artist.Name'].value_counts()
artist_frequency.sort_values().plot(kind='barh',xticks=[n for n in range(0, max(artist_frequency)+1)],color='#7FDBFF',edgecolor='black',figsize=(10,10))
plt.ylabel('Artists')
plt.xlabel('Occurences in Top 50')
plt.title('Occurences of Artists in Top 50')
plt.show()

# %%
# Show top genres
genre_frequency = data['Genre'].value_counts()
genre_frequency.sort_values().plot(kind='barh',xticks=[n for n in range(0, max(genre_frequency)+1)],color='#FFDC00',edgecolor='black',figsize=(10,10))
plt.ylabel('Genre')
plt.xlabel('Occurences in Top 50')
plt.title('Occurences of Genres in Top 50')
plt.show()

# %%
# Show genre frequency using square plot
plt.figure(figsize=(14,8))
genre_counts = data['Genre'].value_counts()
sq.plot(sizes=genre_counts.array,label=genre_counts.index,alpha=.6)
plt.axis('off')
plt.show()

# %%
# Show artist frequency using square plot
plt.figure(figsize=(14,8))
artist_counts = data['Artist.Name'].value_counts()
sq.plot(sizes=artist_counts.array,label=artist_counts.index,alpha=.6)
plt.axis('off')
plt.show()

# %%
# Pairplots
sns.pairplot(data)
plt.show()

# %%
# Pearson Correlation
# Linear relationship correlation
p_corr = data.corr(method='pearson') 
p_corr
# Out:
#                       Rank  Beats.Per.Minute    Energy  Danceability  \
# Rank              1.000000         -0.259193  0.102649      0.122691
# Beats.Per.Minute -0.259193          1.000000  0.043756     -0.094183
# Energy            0.102649          0.043756  1.000000      0.018254
# Danceability      0.122691         -0.094183  0.018254      1.000000
# Loudness..dB..    0.011914          0.017016  0.670794      0.016255
# Liveness          0.270659         -0.167286  0.162768     -0.149636
# Valence.          0.137329         -0.011586  0.438820      0.172829
# Length.          -0.065844         -0.139288  0.224677     -0.000185
# Acousticness..   -0.015993         -0.031450 -0.339892     -0.098165
# Speechiness.     -0.257506          0.557052 -0.089860     -0.103472
# Popularity       -0.160680          0.196097 -0.080295     -0.071413
#
#                   Loudness..dB..  Liveness  Valence.   Length.  \
# Rank                    0.011914  0.270659  0.137329 -0.065844
# ...

# %%
plt.figure(figsize=(15,10))
plt.title('Pearson Correlation Heatmap')
sns.heatmap(p_corr,annot=True,vmin=-1,vmax=1,cmap="rocket",center=1)
htmap_trunc_fix()
plt.show()

# %%
# Spearman Correlation
# Monotonic relationship correlation
sp_corr = data.corr(method='spearman') 
sp_corr
# Out:
#                       Rank  Beats.Per.Minute    Energy  Danceability  \
# Rank              1.000000         -0.262811  0.132029      0.053201
# Beats.Per.Minute -0.262811          1.000000  0.012491     -0.092086
# Energy            0.132029          0.012491  1.000000     -0.048890
# Danceability      0.053201         -0.092086 -0.048890      1.000000
# Loudness..dB..   -0.014465          0.013771  0.635464      0.009268
# Liveness          0.101500         -0.032899  0.013355     -0.261500
# Valence.          0.112640         -0.048304  0.466911      0.154821
# Length.           0.044520         -0.198159  0.188935     -0.078659
# Acousticness..    0.057707         -0.010390 -0.211494     -0.127963
# Speechiness.     -0.232070          0.391641 -0.034860      0.103832
# Popularity       -0.220772          0.217002 -0.044186     -0.140960
#
#                   Loudness..dB..  Liveness  Valence.   Length.  \
# Rank                   -0.014465  0.101500  0.112640  0.044520
# ...

# %%
plt.figure(figsize=(15,10))
plt.title('Spearman Correlation Heatmap')
sns.heatmap(sp_corr,annot=True,vmin=-1,cmap="twilight_shifted_r",vmax=1,center=1)
htmap_trunc_fix()
plt.show()

# %%
# Kendall Tau Correlation
# Ordinal relationship correlation?
    # I still don't fully understand this
k_corr = data.corr(method='kendall') 
k_corr
# Out:
#                       Rank  Beats.Per.Minute    Energy  Danceability  \
# Rank              1.000000         -0.179353  0.076135      0.034670
# Beats.Per.Minute -0.179353          1.000000  0.013406     -0.046803
# Energy            0.076135          0.013406  1.000000     -0.025942
# Danceability      0.034670         -0.046803 -0.025942      1.000000
# Loudness..dB..   -0.016841         -0.000897  0.496912      0.019719
# Liveness          0.087894         -0.045766 -0.009335     -0.175218
# Valence.          0.081215         -0.037376  0.317684      0.091250
# Length.           0.028642         -0.148309  0.131074     -0.052960
# Acousticness..    0.045269         -0.012500 -0.145184     -0.081565
# Speechiness.     -0.171133          0.263299 -0.021260      0.075498
# Popularity       -0.180189          0.151457 -0.037912     -0.085088
#
#                   Loudness..dB..  Liveness  Valence.   Length.  \
# Rank                   -0.016841  0.087894  0.081215  0.028642
# ...

# %%
plt.figure(figsize=(15,10))
plt.title('Kendall Tau Correlation Heatmap')
sns.heatmap(k_corr,annot=True,vmin=-1,cmap="BrBG_r",vmax=1,center=1)
htmap_trunc_fix()
plt.show()

# %%
# We can see that, using three correlation methods, [Energy,Loudness],[Energy,Valence], and [Speachiness, Beats per Minute]
# show the highest r values
