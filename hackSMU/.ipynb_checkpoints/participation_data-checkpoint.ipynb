# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
registrations = pd.read_csv('registrations.csv')
checkIns = pd.read_csv('check-ins.csv')

# %% [markdown]
# # ALL students that signed up for the hackathon, including those that did not attend*

# %%
checkIns
# Out:
#     First Name      Last name                     Email  \
# 0       Scotty           Shaw     scottyshaw1@gmail.com
# 1        Momin          Irfan     Mirfanmomin@gmail.com
# 2      Tristan         Knotts           tknotts@smu.edu
# 3       Kadeem       Palacios  kadeempalacios@gmail.com
# 4         Eli           Laird      elaird03@outlook.com
# ..         ...            ...                       ...
# 239       Muaz          Abrar        mamohammed@smu.edu
# 240    Antoine         Mellon           amellon@smu.edu
# 241  Pritheesh  Panchmahalkar    ppanchmahalkar@smu.edu
# 242        Erb           Uran     erbold.uran@gmail.com
# 243   Kangkang           Yang         kangkangy@smu.edu
#
#                                 School                       Major  \
# 0                      Duke University  Computer Science, Business
# 1        Southern Methodist University  Computer Science, Business
# 2        Southern Methodist University            Computer Science
# ...

# %%
checkIns['Registered'].value_counts()
# Out:
# Male                             198
# Female                            42
# Prefer not to answer               3
# Semi-Automatic Attack Helipad      1
# Name: Gender, dtype: int64

# %%
checkIns['Gender'].value_counts()
# Out:
# Male                             198
# Female                            42
# Prefer not to answer               3
# Semi-Automatic Attack Helipad      1
# Name: Gender, dtype: int64

# %%
checkIns['Shirt Size'].value_counts()
# Out:
# M      128
# L       61
# S       30
# XL      22
# XXL      3
# Name: Shirt Size, dtype: int64

# %%
checkIns['School'].value_counts()
# Out:
# Southern Methodist University           36
# The University of Texas at Arlington    33
# The University of Texas at Dallas       18
# The University of North Texas            6
# Liberty High School                      6
# The University of Texas at Austin        4
# Texas A&M University                     2
# Tarleton State University                1
# Make School Alumni                       1
# Plano West Senior High School            1
# The University of Louisiana Monroe       1
# Texas Woman's University                 1
# Name: School, dtype: int64

# %%
registered = checkIns.loc[checkIns['Registered'] == 'Yes']
registered
# Out:
#     First Name      Last name                          Email  \
# 1        Momin          Irfan          Mirfanmomin@gmail.com
# 2      Tristan         Knotts                tknotts@smu.edu
# 3       Kadeem       Palacios       kadeempalacios@gmail.com
# 9      Michael        O’Keefe               mjokeefe@smu.edu
# 10      Connor         Peters           Cwpeters98@gmail.com
# ..         ...            ...                            ...
# 230     Nikhil        Kushwah          nikskushwah@gmail.com
# 231    Sushant       Deshmukh  sushant.deshmukh@mavs.uta.edu
# 234      yuang            xia                 yuangx@smu.edu
# 239       Muaz          Abrar             mamohammed@smu.edu
# 241  Pritheesh  Panchmahalkar         ppanchmahalkar@smu.edu
#
#                                    School                         Major  \
# 1           Southern Methodist University    Computer Science, Business
# 2           Southern Methodist University              Computer Science
# ...

# %%
registered['Major'].value_counts()
# Out:
# Computer Science                                   71
# Electrical Engineering                             10
# Other Engineering                                   6
# Computer Science, Business                          4
# Business                                            2
# , Not in College yet                                1
# Business, Other Engineering                         1
# , Computer Engineering                              1
# , Software Engineering                              1
# , public policy; economists                         1
# Computer Science, Mathematics                       1
# Business, Computer Science, Economics               1
# , Information Systems                               1
# , Math                                              1
# Computer Science, Electrical Engineering            1
# Business, English & math                            1
# , None                                              1
# ...
